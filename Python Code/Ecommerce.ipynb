# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\AbhilashMandadhi\\Desktop\\Data Sets'

# %%
import numpy as np
import pandas as pd
edata=pd.read_csv("Ecommerce_Customers.csv")
edata
# Out:
#                              Email  \
# 0        mstephenson@fernandez.com
# 1                hduke@hotmail.com
# 2                 pallen@yahoo.com
# 3          riverarebecca@gmail.com
# 4    mstephens@davidson-herman.com
# ..                             ...
# 495   lewisjessica@craig-evans.com
# 496            katrina56@gmail.com
# 497             dale88@hotmail.com
# 498            cwilson@hotmail.com
# 499      hannahwilson@davidson.com
#
#                                                Address  Avg Session Length  \
# 0           835 Frank TunnelWrightmouth, MI 82180-9605           34.497268
# 1         4547 Archer CommonDiazchester, CA 06566-8576           31.926272
# 2    24645 Valerie Unions Suite 582Cobbborough, DC ...           33.000915
# 3       1414 David ThroughwayPort Jason, OH 22070-1220           34.305557
# 4    14023 Rodriguez PassagePort Jacobville, PR 372...           33.330673
# ..                                                 ...                 ...
# ...

# %%
edata.describe()
# Out:
#        Avg Session Length  Time on App  Time on Website  Length of Membership  \
# count          500.000000   500.000000       500.000000            500.000000
# mean            33.053194    12.052488        37.060445              3.533462
# std              0.992563     0.994216         1.010489              0.999278
# min             29.532429     8.508152        33.913847              0.269901
# 25%             32.341822    11.388153        36.349257              2.930450
# 50%             33.082008    11.983231        37.069367              3.533975
# 75%             33.711985    12.753850        37.716432              4.126502
# max             36.139662    15.126994        40.005182              6.922689
#
#        Yearly Amount Spent
# count           500.000000
# mean            499.314038
# std              79.314782
# min             256.670582
# 25%             445.038277
# 50%             498.887875
# 75%             549.313828
# max             765.518462

# %%
edata.corr()
# Out:
#                       Avg Session Length  Time on App  Time on Website  \
# Avg Session Length              1.000000    -0.027826        -0.034987
# Time on App                    -0.027826     1.000000         0.082388
# Time on Website                -0.034987     0.082388         1.000000
# Length of Membership            0.060247     0.029143        -0.047582
# Yearly Amount Spent             0.355088     0.499328        -0.002641
#
#                       Length of Membership  Yearly Amount Spent
# Avg Session Length                0.060247             0.355088
# Time on App                       0.029143             0.499328
# Time on Website                  -0.047582            -0.002641
# Length of Membership              1.000000             0.809084
# Yearly Amount Spent               0.809084             1.000000

# %%
edata.cov()
# Out:
#                       Avg Session Length  Time on App  Time on Website  \
# Avg Session Length              0.985182    -0.027459        -0.035091
# Time on App                    -0.027459     0.988465         0.082771
# Time on Website                -0.035091     0.082771         1.021088
# Length of Membership            0.059756     0.028953        -0.048046
# Yearly Amount Spent            27.954300    39.374988        -0.211655
#
#                       Length of Membership  Yearly Amount Spent
# Avg Session Length                0.059756            27.954300
# Time on App                       0.028953            39.374988
# Time on Website                  -0.048046            -0.211655
# Length of Membership              0.998556            64.125922
# Yearly Amount Spent              64.125922          6290.834573

# %%
edata.head()
# Out:
#                            Email  \
# 0      mstephenson@fernandez.com
# 1              hduke@hotmail.com
# 2               pallen@yahoo.com
# 3        riverarebecca@gmail.com
# 4  mstephens@davidson-herman.com
#
#                                              Address  Avg Session Length  \
# 0         835 Frank TunnelWrightmouth, MI 82180-9605           34.497268
# 1       4547 Archer CommonDiazchester, CA 06566-8576           31.926272
# 2  24645 Valerie Unions Suite 582Cobbborough, DC ...           33.000915
# 3     1414 David ThroughwayPort Jason, OH 22070-1220           34.305557
# 4  14023 Rodriguez PassagePort Jacobville, PR 372...           33.330673
#
#    Time on App  Time on Website  Length of Membership  Yearly Amount Spent
# 0    12.655651        39.577668              4.082621           587.951054
# 1    11.109461        37.268959              2.664034           392.204933
# 2    11.330278        37.110597              4.104543           487.547505
# ...

# %%
edata.tail()
# Out:
#                             Email  \
# 495  lewisjessica@craig-evans.com
# 496           katrina56@gmail.com
# 497            dale88@hotmail.com
# 498           cwilson@hotmail.com
# 499     hannahwilson@davidson.com
#
#                                                Address  Avg Session Length  \
# 495  4483 Jones Motorway Suite 872Lake Jamiefurt, U...           33.237660
# 496    172 Owen Divide Suite 497West Richard, CA 19320           34.702529
# 497  0787 Andrews Ranch Apt. 633South Chadburgh, TN...           32.646777
# 498  680 Jennifer Lodge Apt. 808Brendachester, TX 0...           33.322501
# 499  49791 Rachel Heights Apt. 898East Drewborough,...           33.715981
#
#      Time on App  Time on Website  Length of Membership  Yearly Amount Spent
# 495    13.566160        36.417985              3.746573           573.847438
# 496    11.695736        37.190268              3.576526           529.049004
# ...

# %%
edata.dtypes
# Out:
# Email                    object
# Address                  object
# Avg Session Length      float64
# Time on App             float64
# Time on Website         float64
# Length of Membership    float64
# Yearly Amount Spent     float64
# dtype: object

# %%
#mean_TSOAP=edata['Time on App'].mean()
mean_TSOAP=edata['Time on App'].min()
mean_TSOAP
# Out:
# 8.508152176

# %%
mean_YAS=edata['Yearly Amount Spent'].mean()
#mean_YAS=edata['Yearly Amount Spent'].min()
mean_YAS
# Out:
# 499.3140382608002

# %%
edata.shape
# Out:
# (500, 7)

# %%
edata.pivot_table(edata,index=['Email'])
# Out:
#                                   Avg Session Length  Length of Membership  \
# Email
# aaron04@yahoo.com                          33.705113              4.778974
# aaron11@luna.com                           32.449522              2.941411
# aaron22@gmail.com                          33.452295              4.712234
# aaron89@gmail.com                          31.447446              4.238296
# acampbell@sanchez-velasquez.info           32.425697              2.586968
# ...                                              ...                   ...
# youngellen@hotmail.com                     31.574138              4.560396
# yvaughn@meyer.com                          33.100358              3.612239
# zachary94@gmail.com                        31.312350              3.594295
# zmalone@yahoo.com                          34.536659              3.283663
# zscott@wright.com                          35.630854              4.019051
#
# ...

# %%
edata.pivot_table(edata,index=['Yearly Amount Spent'])
# Out:
#                      Avg Session Length  Length of Membership  Time on App  \
# Yearly Amount Spent
# 256.670582                    32.836941              0.789520    10.256549
# 266.086341                    30.816201              1.084585    11.851399
# 275.918421                    31.517122              1.428824    10.745189
# 282.471246                    30.492537              1.481617    11.562936
# 298.762008                    32.529769              0.801516    11.747732
# ...                                 ...                   ...          ...
# 708.935185                    34.385820              5.705941    12.729720
# 712.396327                    34.967610              5.066697    13.919494
# 725.584814                    33.256335              5.976768    13.858062
# 744.221867                    34.603311              6.922689    12.207298
# 765.518462                    34.374258              5.377594    15.126994
#
#                      Time on Website
# ...

# %%
edata.pivot_table(edata,index=['Time on App'])
# Out:
#              Avg Session Length  Length of Membership  Time on Website  \
# Time on App
# 8.508152              34.102279              1.838211        35.462400
# 8.668350              34.083663              2.252446        35.906756
# 9.316289              33.981006              2.868428        36.914952
# 9.477778              34.357196              5.047023        37.906015
# 9.607315              33.076536              5.081210        36.493993
# ...                         ...                   ...              ...
# 14.288015             31.816428              2.964498        36.773861
# 14.325655             33.708153              3.634340        35.721827
# 14.426491             35.039283              3.930615        37.374184
# 14.715388             32.187812              1.516576        38.244115
# 15.126994             34.374258              5.377594        37.157624
#
#              Yearly Amount Spent
# Time on App
# 8.508152              302.189548
# ...

# %%
edata.pivot_table(edata,index=['Time on Website'])
# Out:
#                  Avg Session Length  Length of Membership  Time on App  \
# Time on Website
# 33.913847                 34.603311              6.922689    12.207298
# 34.476878                 33.871038              5.493507    12.026925
# 34.487185                 33.637812              2.739200    12.039502
# 34.574028                 33.236266              2.931620    10.972554
# 34.649800                 34.211461              4.985205    10.770249
# ...                             ...                   ...          ...
# 39.294043                 32.115119              1.443515    11.919242
# 39.577668                 34.497268              4.082621    12.655651
# 39.600376                 31.514738              3.751735    12.595671
# 39.672591                 33.625307              3.969418    12.988221
# 40.005182                 32.179100              3.552650    11.187539
#
#                  Yearly Amount Spent
# Time on Website
# 33.913847                 744.221867
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
edata['Yearly Amount Spent'].hist(bins=10)

# %%
edata['Length of Membership'].hist(bins=10)

# %%
edata.hist(bins=10, figsize=(10,10),grid=True)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002521F6DE188>,
# ...
#       dtype=object)

# %%
edata.boxplot(column='Time on Website',by='Yearly Amount Spent')

# %%
edata.boxplot(column='Time on App',by='Yearly Amount Spent')

# %%
edata.boxplot(column ='Yearly Amount Spent')

# %%
edata.boxplot(column ='Time on Website')

# %%
edata.boxplot(column ='Time on App')

# %%
edata.boxplot(column='Avg Session Length')

# %%
pd.crosstab(edata['Avg Session Length'],edata['Yearly Amount Spent'],margins=True)
# Out:
# Yearly Amount Spent  256.67058230000004  266.0863409  275.9184207  \
# Avg Session Length
# 29.53242897                           0            0            0
# 30.39318454                           0            0            0
# 30.492536699999995                    0            0            0
# 30.57436368                           0            0            0
# 30.73772037                           0            0            0
# ...                                 ...          ...          ...
# 35.63085386                           0            0            0
# 35.74266981                           0            0            0
# 35.86023651                           0            0            0
# 36.13966249                           0            0            0
# All                                   1            1            1
#
# Yearly Amount Spent  282.4712457  298.7620079  302.1895478  304.1355916  \
# Avg Session Length
# ...
