# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\AbhilashMandadhi\\Desktop\\Data Sets'

# %%
import numpy as np
import pandas as pd
cdata = pd.read_csv("challenger.csv")
cdata
# Out:
#     o_ring_ct  O_ring_failures  temperature  pressure  launch_id
# 0           6                0           66        50          1
# 1           6                1           70        50          2
# 2           6                0           69        50          3
# 3           6                0           68        50          4
# 4           6                0           67        50          5
# 5           6                0           72        50          6
# 6           6                0           73       100          7
# 7           6                0           70       100          8
# 8           6                1           57       200          9
# 9           6                1           63       200         10
# 10          6                1           70       200         11
# 11          6                0           78       200         12
# 12          6                0           67       200         13
# ...

# %%
cdata.describe()
# Out:
#        o_ring_ct  O_ring_failures  temperature    pressure  launch_id
# count       23.0        23.000000    23.000000   23.000000   23.00000
# mean         6.0         0.304348    69.565217  152.173913   12.00000
# std          0.0         0.558796     7.057080   68.221332    6.78233
# min          6.0         0.000000    53.000000   50.000000    1.00000
# 25%          6.0         0.000000    67.000000   75.000000    6.50000
# 50%          6.0         0.000000    70.000000  200.000000   12.00000
# 75%          6.0         0.500000    75.000000  200.000000   17.50000
# max          6.0         2.000000    81.000000  200.000000   23.00000

# %%
cdata.corr()
# Out:
#                  o_ring_ct  O_ring_failures  temperature  pressure  launch_id
# o_ring_ct              NaN              NaN          NaN       NaN        NaN
# O_ring_failures        NaN         1.000000    -0.725671  0.220326  -0.011993
# temperature            NaN        -0.725671     1.000000  0.039818   0.230770
# pressure               NaN         0.220326     0.039818  1.000000   0.839932
# launch_id              NaN        -0.011993     0.230770  0.839932   1.000000

# %%
cdata.cov()
# Out:
#                  o_ring_ct  O_ring_failures  temperature     pressure  \
# o_ring_ct              0.0         0.000000     0.000000     0.000000
# O_ring_failures        0.0         0.312253    -2.861660     8.399209
# temperature            0.0        -2.861660    49.802372    19.169960
# pressure               0.0         8.399209    19.169960  4654.150198
# launch_id              0.0        -0.045455    11.045455   388.636364
#
#                   launch_id
# o_ring_ct          0.000000
# O_ring_failures   -0.045455
# temperature       11.045455
# pressure         388.636364
# launch_id         46.000000

# %%
cdata.head()
# Out:
#    o_ring_ct  O_ring_failures  temperature  pressure  launch_id
# 0          6                0           66        50          1
# 1          6                1           70        50          2
# 2          6                0           69        50          3
# 3          6                0           68        50          4
# 4          6                0           67        50          5

# %%
cdata.tail()
# Out:
#     o_ring_ct  O_ring_failures  temperature  pressure  launch_id
# 18          6                0           76       200         19
# 19          6                0           79       200         20
# 20          6                0           75       200         21
# 21          6                0           76       200         22
# 22          6                1           58       200         23

# %%
cdata.columns
# Out:
# Index(['o_ring_ct', 'O_ring_failures', 'temperature', 'pressure', 'launch_id'], dtype='object')

# %%
cdata.shape
# Out:
# (23, 5)

# %%
cdata.dtypes
# Out:
# o_ring_ct          int64
# O_ring_failures    int64
# temperature        int64
# pressure           int64
# launch_id          int64
# dtype: object

# %%
cdata['temperature'].unique()
# Out:
# array([66, 70, 69, 68, 67, 72, 73, 57, 63, 78, 53, 75, 81, 76, 79, 58],
#       dtype=int64)

# %%
cdata['pressure'].unique()
# Out:
# array([ 50, 100, 200], dtype=int64)

# %%
cdata['O_ring_failures'].unique()
# Out:
# array([0, 1, 2], dtype=int64)

# %%
mean_temp= cdata['temperature'].max()
mean_temp
# Out:
# 81

# %%
mean_press= cdata['pressure'].max()
mean_press
# Out:
# 200

# %%
cdata.pivot_table(cdata,index=['temperature'])
# Out:
#              O_ring_failures  launch_id  o_ring_ct  pressure
# temperature
# 53                       2.0       14.0          6     200.0
# 57                       1.0        9.0          6     200.0
# 58                       1.0       23.0          6     200.0
# 63                       1.0       10.0          6     200.0
# 66                       0.0        1.0          6      50.0
# 67                       0.0       11.0          6     150.0
# 68                       0.0        4.0          6      50.0
# 69                       0.0        3.0          6      50.0
# 70                       0.5        9.5          6     137.5
# 72                       0.0        6.0          6      50.0
# 73                       0.0        7.0          6     100.0
# 75                       0.0       18.5          6     200.0
# 76                       0.0       20.5          6     200.0
# 78                       0.0       12.0          6     200.0
# ...

# %%
cdata.pivot_table(cdata,index=['pressure'])
# Out:
#           O_ring_failures  launch_id  o_ring_ct  temperature
# pressure
# 50               0.166667        3.5          6    68.666667
# 100              0.000000        7.5          6    71.500000
# 200              0.400000       16.0          6    69.666667

# %%
cdata.pivot_table(cdata,index=['O_ring_failures'])
# Out:
#                  launch_id  o_ring_ct    pressure  temperature
# O_ring_failures
# 0                12.176471          6  144.117647    72.294118
# 1                11.000000          6  170.000000    63.600000
# 2                14.000000          6  200.000000    53.000000

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
cdata['temperature'].hist(bins=10)

# %%
cdata['pressure'].hist(bins=10)

# %%
cdata.hist(bins=10, figsize=(20,20),grid=True)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002316BDC4E88>,
# ...
#       dtype=object)

# %%
cdata.boxplot(column ='O_ring_failures', by='temperature')

# %%
cdata.boxplot(column ='pressure', by='temperature')

# %%
pd.crosstab(cdata['temperature'],cdata['O_ring_failures'],margins=True)
# Out:
# O_ring_failures   0  1  2  All
# temperature
# 53                0  0  1    1
# 57                0  1  0    1
# 58                0  1  0    1
# 63                0  1  0    1
# 66                1  0  0    1
# 67                3  0  0    3
# 68                1  0  0    1
# 69                1  0  0    1
# 70                2  2  0    4
# 72                1  0  0    1
# 73                1  0  0    1
# 75                2  0  0    2
# 76                2  0  0    2
# 78                1  0  0    1
# 79                1  0  0    1
# 81                1  0  0    1
# All              17  5  1   23

# %%
pd.crosstab(cdata['temperature'],cdata['pressure'],margins=True)
# Out:
# pressure     50  100  200  All
# temperature
# 53            0    0    1    1
# 57            0    0    1    1
# 58            0    0    1    1
# 63            0    0    1    1
# 66            1    0    0    1
# 67            1    0    2    3
# 68            1    0    0    1
# 69            1    0    0    1
# 70            1    1    2    4
# 72            1    0    0    1
# 73            0    1    0    1
# 75            0    0    2    2
# 76            0    0    2    2
# 78            0    0    1    1
# 79            0    0    1    1
# 81            0    0    1    1
# All           6    2   15   23
